# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
chang = pd.read_csv('~/Documents/changping.csv')

# %%
chang
# Out:
#           No  year  month  day  hour  PM2.5  PM10   SO2   NO2     CO    O3  \
# 0          1  2013      3    1     0    3.0   6.0  13.0   7.0  300.0  85.0
# 1          2  2013      3    1     1    3.0   3.0   6.0   6.0  300.0  85.0
# 2          3  2013      3    1     2    3.0   3.0  22.0  13.0  400.0  74.0
# 3          4  2013      3    1     3    3.0   6.0  12.0   8.0  300.0  81.0
# 4          5  2013      3    1     4    3.0   3.0  14.0   8.0  300.0  81.0
# ...      ...   ...    ...  ...   ...    ...   ...   ...   ...    ...   ...
# 35059  35060  2017      2   28    19   28.0  47.0   4.0  14.0  300.0   NaN
# 35060  35061  2017      2   28    20   12.0  12.0   3.0  23.0  500.0  64.0
# 35061  35062  2017      2   28    21    7.0  23.0   5.0  17.0  500.0  68.0
# 35062  35063  2017      2   28    22   11.0  20.0   3.0  15.0  500.0  72.0
# 35063  35064  2017      2   28    23   20.0  25.0   6.0  28.0  900.0  54.0
#
#        TEMP    PRES  DEWP  RAIN   wd  WSPM    station
# ...

# %%
features = ['PM2.5', 'PM10', 'SO2', 'NO2', 'CO', 'O3', 'TEMP', 'PRES', 'DEWP', 'RAIN', 'WSPM']
chang1 = chang[features]
chang1
# Out:
#        PM2.5  PM10   SO2   NO2     CO    O3  TEMP    PRES  DEWP  RAIN  WSPM
# 0        3.0   6.0  13.0   7.0  300.0  85.0  -2.3  1020.8 -19.7   0.0   0.5
# 1        3.0   3.0   6.0   6.0  300.0  85.0  -2.5  1021.3 -19.0   0.0   0.7
# 2        3.0   3.0  22.0  13.0  400.0  74.0  -3.0  1021.3 -19.9   0.0   0.2
# 3        3.0   6.0  12.0   8.0  300.0  81.0  -3.6  1021.8 -19.1   0.0   1.0
# 4        3.0   3.0  14.0   8.0  300.0  81.0  -3.5  1022.3 -19.4   0.0   2.1
# ...      ...   ...   ...   ...    ...   ...   ...     ...   ...   ...   ...
# 35059   28.0  47.0   4.0  14.0  300.0   NaN  11.7  1008.9 -13.3   0.0   1.3
# 35060   12.0  12.0   3.0  23.0  500.0  64.0  10.9  1009.0 -14.0   0.0   2.1
# 35061    7.0  23.0   5.0  17.0  500.0  68.0   9.5  1009.4 -13.0   0.0   1.5
# 35062   11.0  20.0   3.0  15.0  500.0  72.0   7.8  1009.6 -12.6   0.0   1.4
# 35063   20.0  25.0   6.0  28.0  900.0  54.0   7.0  1009.4 -12.2   0.0   1.9
#
# [35064 rows x 11 columns]

# %%
sns.pairplot(chang1)
plt.show()

# %%
plt.figure(figsize = (20, 20))
sns.set(font_scale = 2)
sns.heatmap(chang1.corr(), annot = True)
# Out:
# <AxesSubplot:>
